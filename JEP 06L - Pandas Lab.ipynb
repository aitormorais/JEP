# %% [markdown]
# -sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Pandas Lab
#
# In this lab, you will use [pandas](https://pandas.pydata.org/docs/) for basic data manipulation.

# %% [markdown]
# Create a DataFrame called `df` with 3 columns and 3 rows with integers like in the following image. It should also have the appropriate column names.
#
# ![DataFrame](https://files.training.databricks.com/images/create_dataframe.png)

# %%
# TODO
import pandas as pd
one = [1,4,7]
two = [2,5,8]
three = [3,6,9]
df = pd.DataFrame()
df["one"]=one
df["two"]=two
df["three"]=three
print(df)
# Out:
#    one  two  three
# 0    1    2      3
# 1    4    5      6
# 2    7    8      9

# %% [markdown]
# Display a DataFrame that only has the column `three`.

# %%
# TODO
df[["three"]]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>three</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Return a Series (not DataFrame) object which just contains the values from the column `three`.

# %%
# TODO
df["three"]
# Out:
# Out[4]: 0    3
# 1    6
# 2    9
# Name: three, dtype: int64

# %% [markdown]
# Programmatically extract the number `5` from `df`. Which column and row do you need to access?

# %%
# TODO
df["two"][1]
# Out:
# Out[5]: 5

# %% [markdown]
# Add a new column called `row sum` to `df` which contains the sum of entries across each row in `df`.

# %%
# TODO

  
df["row sum"] = df["one"] + df["two"]+df["three"]
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>one</th><th>two</th><th>three</th><th>row sum</th></tr></thead><tbody><tr><td>1</td><td>2</td><td>3</td><td>6</td></tr><tr><td>4</td><td>5</td><td>6</td><td>15</td></tr><tr><td>7</td><td>8</td><td>9</td><td>24</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
